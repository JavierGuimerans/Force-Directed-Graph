# %%
# !pip install d3fdgraph

# %%
import d3fdgraph
import pandas as pd

# %%
df = pd.read_csv('stormofswords.csv')

# %%
df.head()
# Out:
#   Source   Target  Weight
# 0  Aemon    Grenn       5
# 1  Aemon  Samwell      31
# 2  Aerys    Jaime      18
# 3  Aerys   Robert       6
# 4  Aerys   Tyrion       5

# %%
d3fdgraph.plot_force_directed_graph(df, node_radius=5, link_distance=300, collision_scale=2, link_width_scale=4)
# Out:
# <script src="/static/components/requirejs/require.js"></script>
# <div id="d3-container-9577041"></div>
# <div>force-directed graph</div>
#
# <style>
#     .links line {
#         stroke: #88d;
#         stroke-opacity: .2;
#     }
#     .nodes circle {
#         pointer-events: all;
#         stroke: #fff;
#         fill: #a55;
#         stroke-width: 1.5px;
#         opacity: 0.7;
#     }
#     .nodes text {
#         pointer-events: none;
#         font: 10px sans-serif;
#         fill: #333;
#         opacity: .5;
#     }
# </style>
